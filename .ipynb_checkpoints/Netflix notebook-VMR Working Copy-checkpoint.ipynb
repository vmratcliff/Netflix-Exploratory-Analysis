# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
netflix_df = pd.read_csv("netflix_titles_corrected.csv")
netflix_df.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country date_added_corrected  \
# 0  United States, India, South Korea, China               9/9/19
# 1                            United Kingdom               9/9/16
# 2                             United States               9/8/18
# 3                             United States               9/8/18
# 4                             United States               9/8/17
#
#    release_year    rating  duration                           listed_in  \
# 0          2019     TV-PG    90 min  Children & Family Movies, Comedies
# 1          2016     TV-MA    94 min                     Stand-Up Comedy
# 2          2013  TV-Y7-FV  1 Season                            Kids' TV
# 3          2016     TV-Y7  1 Season                            Kids' TV
# 4          2017     TV-14    99 min                            Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...
# 1  Jandino Asporaat riffs on the challenges of ra...
# 2  With the help of three human allies, the Autob...
# 3  When a prison ship crash unleashes hundreds of...
# 4  When nerdy high schooler Dani finally attracts...

# %%
# dropping null value columns to avoid errors
netflix_df.dropna(inplace = True)

# %%
# new data frame with split value columns 
file = netflix_df["listed_in"].str.split(",", n = 1, expand = True)

# %%
# making separate genre category column from new data frame 
netflix_df["Genre Main Category"]= file[0]

# %%
# making separate sub category column from new data frame
netflix_df["Genre Sub Category"]= file[1]

# %%
netflix_df.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 9                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
# 9  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
#                                           country date_added_corrected  \
# 0        United States, India, South Korea, China               9/9/19
# 4                                   United States               9/8/17
# 6          Bulgaria, United States, Spain, Canada               9/8/17
# 7                                           Chile               9/8/17
# 9  United States, United Kingdom, Denmark, Sweden               9/8/17
#
#    release_year rating duration  \
# 0          2019  TV-PG   90 min
# 4          2017  TV-14   99 min
# 6          2014      R  110 min
# 7          2017  TV-MA   60 min
# 9          2014      R   90 min
#
#                                            listed_in  \
# 0                 Children & Family Movies, Comedies
# 4                                           Comedies
# 6  International Movies, Sci-Fi & Fantasy, Thrillers
# 7                                    Stand-Up Comedy
# 9                      Action & Adventure, Thrillers
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# 4  When nerdy high schooler Dani finally attracts...
# 6  In a dystopian future, an insurance adjuster f...
# 7  Fabrizio Copano takes audience participation t...
# 9  A struggling couple can't believe their luck w...
#
#         Genre Main Category            Genre Sub Category
# 0  Children & Family Movies                      Comedies
# 4                  Comedies                          None
# 6      International Movies   Sci-Fi & Fantasy, Thrillers
# 7           Stand-Up Comedy                          None
# 9        Action & Adventure                     Thrillers

# %%
netflix_df["year added"] = ""
netflix_df.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 9                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
# 9  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
#                                           country date_added_corrected  \
# 0        United States, India, South Korea, China               9/9/19
# 4                                   United States               9/8/17
# 6          Bulgaria, United States, Spain, Canada               9/8/17
# 7                                           Chile               9/8/17
# 9  United States, United Kingdom, Denmark, Sweden               9/8/17
#
#    release_year rating duration  \
# 0          2019  TV-PG   90 min
# 4          2017  TV-14   99 min
# 6          2014      R  110 min
# 7          2017  TV-MA   60 min
# 9          2014      R   90 min
#
#                                            listed_in  \
# 0                 Children & Family Movies, Comedies
# 4                                           Comedies
# 6  International Movies, Sci-Fi & Fantasy, Thrillers
# 7                                    Stand-Up Comedy
# 9                      Action & Adventure, Thrillers
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# 4  When nerdy high schooler Dani finally attracts...
# 6  In a dystopian future, an insurance adjuster f...
# 7  Fabrizio Copano takes audience participation t...
# 9  A struggling couple can't believe their luck w...
#
#         Genre Main Category            Genre Sub Category year added
# 0  Children & Family Movies                      Comedies
# 4                  Comedies                          None
# 6      International Movies   Sci-Fi & Fantasy, Thrillers
# 7           Stand-Up Comedy                          None
# 9        Action & Adventure                     Thrillers

# %%
netflix_df['date_added_corrected'] = pd.to_datetime(netflix_df['date_added_corrected'])
netflix_df['year added'] = netflix_df['date_added_corrected'].dt.year
netflix_df.head()
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
# 4  80125979  Movie                             #realityhigh
# 6  70304989  Movie                                 Automata
# 7  80164077  Movie       Fabrizio Copano: Solo pienso en mi
# 9  70304990  Movie                              Good People
#
#                           director  \
# 0         Richard Finn, Tim Maltby
# 4                 Fernando Lebrija
# 6                      Gabe Ibáñez
# 7  Rodrigo Toro, Francisco Schultz
# 9                Henrik Ruben Genz
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6  Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                    Fabrizio Copano
# 9  James Franco, Kate Hudson, Tom Wilkinson, Omar...
#
#                                           country date_added_corrected  \
# 0        United States, India, South Korea, China           2019-09-09
# 4                                   United States           2017-09-08
# 6          Bulgaria, United States, Spain, Canada           2017-09-08
# 7                                           Chile           2017-09-08
# 9  United States, United Kingdom, Denmark, Sweden           2017-09-08
#
#    release_year rating duration  \
# 0          2019  TV-PG   90 min
# 4          2017  TV-14   99 min
# 6          2014      R  110 min
# 7          2017  TV-MA   60 min
# 9          2014      R   90 min
#
#                                            listed_in  \
# 0                 Children & Family Movies, Comedies
# 4                                           Comedies
# 6  International Movies, Sci-Fi & Fantasy, Thrillers
# 7                                    Stand-Up Comedy
# 9                      Action & Adventure, Thrillers
#
#                                          description  \
# 0  Before planning an awesome wedding for his gra...
# 4  When nerdy high schooler Dani finally attracts...
# 6  In a dystopian future, an insurance adjuster f...
# 7  Fabrizio Copano takes audience participation t...
# 9  A struggling couple can't believe their luck w...
#
#         Genre Main Category            Genre Sub Category  year added
# 0  Children & Family Movies                      Comedies        2019
# 4                  Comedies                          None        2017
# 6      International Movies   Sci-Fi & Fantasy, Thrillers        2017
# 7           Stand-Up Comedy                          None        2017
# 9        Action & Adventure                     Thrillers        2017

# %%
# Generate a pie plot showing the distribution of Movies vs TV Shows using pandas
production_type = netflix_df.groupby('type')

# create a DataFrame
production_type_count = pd.DataFrame(production_type['type'].count())
production_type_count
# Out:
#          type
# type
# Movie    3678
# TV Show    96

# %%
fig, ax = plt.subplots()

production_type_count.plot(kind='pie', y="type", colors=["orange", "lightskyblue"], autopct='%1.1f%%', shadow=True, startangle=140, legend=False, ax=ax)

ax.set_ylabel('Production Type')
ax.set_title("Production Type Distribution of Netflix Offerings")
# add time period in title
# Out:
# Text(0.5, 1.0, 'Production Type Distribution of Netflix Offerings')

# %%
# Production Type count by year added
type_count = netflix_df.groupby(['year added', 'type'])

type_year = type_count['type'].count()
type_year
# Out:
# year added  type
# 2008        Movie         1
# 2009        Movie         2
# 2010        Movie         1
# 2011        Movie        13
# 2012        Movie         4
# 2013        Movie         6
#             TV Show       1
# 2014        Movie        14
# 2015        Movie        47
#             TV Show       3
# 2016        Movie       204
#             TV Show       7
# 2017        Movie       778
#             TV Show      27
# 2018        Movie      1122
#             TV Show      18
# 2019        Movie      1347
#             TV Show      39
# 2020        Movie       139
#             TV Show       1
# Name: type, dtype: int64

# %%
# Bar Chart: Production Type count by year added
fig, ax = plt.subplots()

tv_shows = netflix_df['type'].count() == "TV Show"
movies = netflix_df['type'].count() == "Movies"
index = netflix_df['year added']

type_year_df = pd.DataFrame({'TV Shows': tv_shows, 'Movies': movies}, index=index)
type_year_df.plot(kind="bar", title="TV Shows & Movies Added By Year", legend=True, ax=ax)
ax.set_xlabel("Year")
ax.set_ylabel("Count")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-82746e1c16af> in <module>
#       7
#       8 type_year_df = pd.DataFrame({'TV Shows': tv_shows, 'Movies': movies}, index=index)
# ----> 9 type_year_df.plot(kind="bar", title="TV Shows & Movies Added By Year", legend=True, ax=ax)
#      10 ax.set_xlabel("Year")
#      11 ax.set_ylabel("Count")
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     277     def generate(self):
#     278         self._args_adjust()
# --> 279         self._compute_plot_data()
#     280         self._setup_subplots()
#     281         self._make_plot()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py in _compute_plot_data(self)
#     412         # no non-numeric frames or series allowed
#     413         if is_empty:
# --> 414             raise TypeError("no numeric data to plot")
#     415
#     416         # GH25587: cast ExtensionArray of pandas (IntegerArray, etc.) to
#
# TypeError: no numeric data to plot

# %%
# create bar chart showing genre Main Category content added over the years - Overall
genre_main = netflix_df.groupby("Genre Main Category")

genre_main_count = pd.DataFrame(genre_main["Genre Main Category"].count())
genre_main_count
# Out:
#                               Genre Main Category
# Genre Main Category
# Action & Adventure                            583
# Anime Features                                 10
# Anime Series                                    8
# British TV Shows                               17
# Children & Family Movies                      304
# Classic & Cult TV                               1
# Classic Movies                                 54
# Comedies                                      767
# Crime TV Shows                                 19
# Cult Movies                                    10
# Documentaries                                 295
# Docuseries                                      4
# Dramas                                       1045
# Horror Movies                                 202
# Independent Movies                             18
# International Movies                           75
# International TV Shows                         24
# Kids' TV                                        8
# Movies                                         20
# Music & Musicals                                9
# Romantic Movies                                 2
# Sci-Fi & Fantasy                               10
# Stand-Up Comedy                               234
# Stand-Up Comedy & Talk Shows                    5
# TV Action & Adventure                           2
# TV Comedies                                     2
# TV Dramas                                       1
# TV Horror                                       1
# TV Shows                                        4
# Thrillers                                      40

# %%
# create bar chart showing number of movies & tv shows added over the years - (each year)

# %%
genre_df = genre_main_count.drop(['Movies', 'TV Shows'])
genre_df
# Out:
#                               Genre Main Category
# Genre Main Category
# Action & Adventure                            583
# Anime Features                                 10
# Anime Series                                    8
# British TV Shows                               17
# Children & Family Movies                      304
# Classic & Cult TV                               1
# Classic Movies                                 54
# Comedies                                      767
# Crime TV Shows                                 19
# Cult Movies                                    10
# Documentaries                                 295
# Docuseries                                      4
# Dramas                                       1045
# Horror Movies                                 202
# Independent Movies                             18
# International Movies                           75
# International TV Shows                         24
# Kids' TV                                        8
# Music & Musicals                                9
# Romantic Movies                                 2
# Sci-Fi & Fantasy                               10
# Stand-Up Comedy                               234
# Stand-Up Comedy & Talk Shows                    5
# TV Action & Adventure                           2
# TV Comedies                                     2
# TV Dramas                                       1
# TV Horror                                       1
# Thrillers                                      40

# %%
fig, ax = plt.subplots()
genre_df.plot(kind='bar', title="Genre Distribution Over the Years", legend=False, ax=ax)
ax.set_xlabel("Genre Main Category")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
# create bar chart showing Ratings content added over the years - Overall
# create bar chart showing genre Main Category content added over the years - Overall
ratings_count = netflix_df.groupby("rating")

ratings_count_df = pd.DataFrame(ratings_count["rating"].count())
ratings_count_df
# Out:
#           rating
# rating
# G             35
# NC-17          1
# NR           175
# PG           176
# PG-13        278
# R            501
# TV-14        917
# TV-G          54
# TV-MA       1189
# TV-PG        358
# TV-Y          24
# TV-Y7         48
# TV-Y7-FV      11
# UR             7

# %%
fig, ax = plt.subplots()
ratings_count_df.plot(kind='bar', title="Ratings Distribution Over the Years", legend=False, ax=ax)
ax.set_xlabel("Ratings")
ax.set_ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')
